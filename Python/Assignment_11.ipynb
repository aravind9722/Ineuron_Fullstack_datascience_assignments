# %% [markdown]
# **1.Create an assert statement that throws an AssertionError if the variable spam is a negative integer.**

# %%
spam = 36
assert spam <=0, 'Variable Spam should not be a +ve number'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-2cfd1f8bde45> in <module>()
#       1 spam = 36
# ----> 2 assert spam <=0, 'Variable Spam should not be a +ve number'
#
# AssertionError: Variable Spam should not be a +ve number

# %% [markdown]
# **2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different (that is, 'hello' and 'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).**

# %%
def raise_assert(egg,bacon):
    egg = egg.upper()
    bacon = bacon.upper()
    assert not(egg == bacon), 'Eggs/Bacon is same , it should not be same'

raise_assert('hello', 'HELLO')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-3730b30b52f6> in <module>()
#       4     assert not(egg == bacon), 'Eggs/Bacon is same , it should not be same'
#       5
# ----> 6 raise_assert('hello', 'HELLO')
#
# <ipython-input-3-3730b30b52f6> in raise_assert(egg, bacon)
#       2     egg = egg.upper()
#       3     bacon = bacon.upper()
# ----> 4     assert not(egg == bacon), 'Eggs/Bacon is same , it should not be same'
#       5
#       6 raise_assert('hello', 'HELLO')
#
# AssertionError: Eggs/Bacon is same , it should not be same

# %% [markdown]
# **3. Create an assert statement that throws an AssertionError every time.**

# %%
def assert_error():
    assert False, 'Assertion Error everytime'
assert_error()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-d1381ee37f2d> in <module>()
#       1 def assert_error():
#       2     assert False, 'Assertion Error everytime'
# ----> 3 assert_error()
#
# <ipython-input-5-d1381ee37f2d> in assert_error()
#       1 def assert_error():
# ----> 2     assert False, 'Assertion Error everytime'
#       3 assert_error()
#
# AssertionError: Assertion Error everytime

# %% [markdown]
# **4. What are the two lines that must be present in your software in order to call logging.debug()?**

# %%
import logging
logging.basicConfig(filename = 'application_log.txt',level=logging.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# **5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?**

# %%
import logging
logging.basicConfig(filename = 'programLog.txt',level=logging.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')
logging.debug("Logging message")

# %% [markdown]
# **6. What are the five levels of logging?**
#
# `DEBUG, INFO, WARNING, ERROR, and CRITICAL`

# %% [markdown]
# **7. What line of code would you add to your software to disable all logging messages?**
#
# `logging.disable(logging.CRITICAL)` or `logging.disable = True`

# %% [markdown]
# **8.Why is using logging messages better than using print() to display the same message?**
#
# You can disable logging messages without removing the logging function calls. if you remove print its time consuming.
#
# You can selectively disable lower-level logging messages. You can create logging messages. Logging messages provides a timestamp.
#
# in print we cannot get those extra informations so logging messages are better

# %% [markdown]
# 9.What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
#
#
# The Differences between Step Over, Step In, Step Out buttons in debugger are:
#
# * The Step button will move the debugger into a function call. The Over button will quickly execute the function call without stepping into it.
# * The Out button will quickly execute the rest of the code until it steps out of the function it currently is in.

# %% [markdown]
# **10.After you click Continue, when will the debugger stop ?**
#
# After you click Continue, it will run normally the debugger will stop when it has reached the end of the program or a line with a breakpoint.

# %% [markdown]
# **11. What is the concept of a breakpoint?**
#
# Breakpoint is a setting on a line of code that causes the debugger to pause when the program execution reaches the line
