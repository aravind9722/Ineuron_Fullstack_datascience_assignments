# %% [markdown]
# **1.To what does a relative path refer?**
#
# A relative path refers to a location that is relative to current working directory `(PWD)`.
#
# PWD + relative path = absolute path

# %% [markdown]
# **2.What does an absolute path start with your operating system?**
#
# An absolute file path from the root of `drive C:` in windows operating system

# %% [markdown]
# **3.What do the functions `os.getcwd()` and `os.chdir()` do?**
#
# os.getcwd() method tells us the location of `current working directory` (CWD). Whereas os.chdir() method in Python used to `change the current working directory `to specified path.

# %% [markdown]
# **4.What are the `.` and `..` folders?**
#
# `. `Represents the Current Directory Whereas `..` Represents the Parent Directory of the Current Directory

# %% [markdown]
# **5.In C:\bacon\eggs\spam.txt which part is the dir name and which part is the base name ?**
#
# The dir name is `C:\\bacon\\eggs`
#
# The Base name is `spam.txt`

# %% [markdown]
# **6.What are the three “mode” arguments that can be passed to the open() function?**
#
# A file can be Accessed in python using `open()` function. open function takes two arguments filename and mode of operation (optional). if mode is not provided the default mode of opening is read mode
#
# So, the syntax being: `open(filename, mode)`
#
# modes :  read `'r'`, write `'w'`, Append `'a'` modes are three main modes

# %% [markdown]
# **7.What happens if an existing file is opened in write mode ?**
#
# Using this mode will overwrite any existing content in a file. If the given file does not exist, a new one will be created.

# %% [markdown]
# **8.How do you tell the difference between `read()` and `readlines()`?**
#
# The `read()` would treat each character in the file separately, meaning that the iteration would happen for every character.
#
# The `readline()` function, on the other hand, only reads a single line of the file. This means that if the file file_1 were three lines long, the `readline()` function would only parse (or iterate/operate) on the first line of the file.

# %% [markdown]
# **9.What data structure does a shelf value resemble ?**
#
# it contains key and values it represents dictionary.
